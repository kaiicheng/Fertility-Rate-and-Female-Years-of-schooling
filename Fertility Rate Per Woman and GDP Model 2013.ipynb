# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Fertility Rate and Education Relationship Data 2013.xlsx")
df.head(15)
# Out:
#     Country_Name  Fertility rate, total (births per woman) 2013  \
# 0    Afghanistan                                          5.359
# 1        Albania                                          1.690
# 2        Algeria                                          2.990
# 3      Argentina                                          2.322
# 4        Armenia                                          1.728
# 5      Australia                                          1.855
# 6        Austria                                          1.440
# 7     Azerbaijan                                          1.980
# 8   Bahamas, The                                          1.810
# 9        Bahrain                                          2.098
# 10    Bangladesh                                          2.188
# 11      Barbados                                          1.630
# 12       Belarus                                          1.668
# 13       Belgium                                          1.760
# 14        Belize                                          2.539
#
#     GDP (current US$) 2013  GDP per capita (current US$) 2013  \
# 0             2.056107e+10                         637.165523
# 1             1.277622e+10                        4413.060861
# 2             2.097548e+11                        5499.581487
# 3             5.520251e+11                       13080.254732
# 4             1.112147e+10                        3838.185801
# 5             1.576184e+12                       68150.107041
# 6             4.300687e+11                       50716.708706
# 7             7.416444e+10                        7875.756953
# 8             1.056270e+10                       28768.029894
# 9             3.253947e+10                       24744.296959
# 10            1.499905e+11                         981.839879
# 11            4.677000e+09                       16451.163576
# 12            7.552798e+10                        7978.872615
# 13            5.216427e+11                       46744.662544
# 14            1.579400e+09                        4568.502958
#
#     Mean years of schooling, female (years) 2013
# 0                                            1.4
# 1                                            9.8
# 2                                            6.0
# 3                                           10.5
# 4                                           11.5
# 5                                           12.2
# 6                                           11.5
# 7                                           10.2
# 8                                           11.5
# 9                                            8.9
# 10                                           4.7
# 11                                          10.8
# 12                                          12.0
# 13                                          11.2
# 14                                           9.4

# %%
df
# Out:
#     Country_Name  Fertility rate, total (births per woman) 2013  \
# 0    Afghanistan                                          5.359
# 1        Albania                                          1.690
# 2        Algeria                                          2.990
# 3      Argentina                                          2.322
# 4        Armenia                                          1.728
# ..           ...                                            ...
# 163      Vietnam                                          1.978
# 164  Yemen, Rep.                                          4.326
# 165       Zambia                                          5.132
# 166     Zimbabwe                                          4.030
# 167       Taiwan                                          1.070
#
#      GDP (current US$) 2013  GDP per capita (current US$) 2013  \
# 0              2.056107e+10                         637.165523
# 1              1.277622e+10                        4413.060861
# 2              2.097548e+11                        5499.581487
# 3              5.520251e+11                       13080.254732
# 4              1.112147e+10                        3838.185801
# ..                      ...                                ...
# 163            1.712220e+11                        1886.671896
# 164            4.041524e+10                        1607.152365
# 165            2.804551e+10                        1878.907001
# 166            1.909102e+10                        1430.000818
# 167            5.129570e+11                       21973.000000
#
#      Mean years of schooling, female (years) 2013
# 0                                             1.4
# 1                                             9.8
# 2                                             6.0
# 3                                            10.5
# 4                                            11.5
# ..                                            ...
# 163                                           7.5
# 164                                           1.7
# 165                                           6.2
# 166                                           7.3
# 167                                          11.2
#
# [168 rows x 5 columns]

# %%
print(df['Fertility rate, total (births per woman) 2013'])
# Out:
# 0      5.359
# 1      1.690
# 2      2.990
# 3      2.322
# 4      1.728
#        ...
# 163    1.978
# 164    4.326
# 165    5.132
# 166    4.030
# 167    1.070
# Name: Fertility rate, total (births per woman) 2013, Length: 168, dtype: float64

# %%
print(df['GDP (current US$) 2013'])
# Out:
# 0      2.056107e+10
# 1      1.277622e+10
# 2      2.097548e+11
# 3      5.520251e+11
# 4      1.112147e+10
#            ...
# 163    1.712220e+11
# 164    4.041524e+10
# 165    2.804551e+10
# 166    1.909102e+10
# 167    5.129570e+11
# Name: GDP (current US$) 2013, Length: 168, dtype: float64

# %%
X = df['GDP (current US$) 2013']
y = df['Fertility rate, total (births per woman) 2013']

# %%
X
# Out:
# 0      2.056107e+10
# 1      1.277622e+10
# 2      2.097548e+11
# 3      5.520251e+11
# 4      1.112147e+10
#            ...
# 163    1.712220e+11
# 164    4.041524e+10
# 165    2.804551e+10
# 166    1.909102e+10
# 167    5.129570e+11
# Name: GDP (current US$) 2013, Length: 168, dtype: float64

# %%
y
# Out:
# 0      5.359
# 1      1.690
# 2      2.990
# 3      2.322
# 4      1.728
#        ...
# 163    1.978
# 164    4.326
# 165    5.132
# 166    4.030
# 167    1.070
# Name: Fertility rate, total (births per woman) 2013, Length: 168, dtype: float64

# %%
length = len(df['Country_Name'])

# %%
country_name = df['Country_Name']

# %%
country_tag = df['Country_Name']

# %%
# Create a plot.
plt.figure(figsize = (20, 15))

plt.scatter(X, y)
plt.title("2013")
plt.xlabel("GDP (current US$)")
plt.ylabel("Fertility rate, total (births per woman)")

# Add country name tag.
for i in range(length):
    if country_name[i] == "Taiwan":
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "green", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)
    else:
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "r", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)

plt.show()

# %%
# Ordinary least square method.

# %%
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                               OLS Regression Results
# ==================================================================================================================
# Dep. Variable:     Fertility rate, total (births per woman) 2013   R-squared (uncentered):                   0.026
# Model:                                                       OLS   Adj. R-squared (uncentered):              0.020
# Method:                                            Least Squares   F-statistic:                              4.494
# Date:                                           Tue, 01 Sep 2020   Prob (F-statistic):                      0.0355
# Time:                                                   23:15:59   Log-Likelihood:                         -427.63
# No. Observations:                                            168   AIC:                                      857.3
# Df Residuals:                                                167   BIC:                                      860.4
# Df Model:                                                      1
# Covariance Type:                                       nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# GDP (current US$) 2013   3.03e-13   1.43e-13      2.120      0.035    2.08e-14    5.85e-13
# ==============================================================================
# Omnibus:                        7.041   Durbin-Watson:                   0.471
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                7.109
# Skew:                           0.384   Prob(JB):                       0.0286
# Kurtosis:                       3.652   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Replace X with log(X)

# %%
X = np.log(X)

# %%
X
# Out:
# 0      23.746665
# 1      23.270851
# 2      26.069205
# 3      27.036859
# 4      23.132143
#          ...
# 163    25.866227
# 164    24.422473
# 165    24.057094
# 166    23.672484
# 167    26.963458
# Name: GDP (current US$) 2013, Length: 168, dtype: float64

# %%
y
# Out:
# 0      5.359
# 1      1.690
# 2      2.990
# 3      2.322
# 4      1.728
#        ...
# 163    1.978
# 164    4.326
# 165    5.132
# 166    4.030
# 167    1.070
# Name: Fertility rate, total (births per woman) 2013, Length: 168, dtype: float64

# %%
# Create a plot.
plt.figure(figsize = (20, 15))

plt.scatter(X, y)
plt.title("2013")
plt.xlabel("GDP (current US$)")
plt.ylabel("Birth rate, crude (per 1,000 people)")

# Add country name tag.
for i in range(length):
    if country_name[i] == "Taiwan":
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "green", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)
    else:
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "r", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)

plt.show()

# %%
# Ordinary least square method.
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                               OLS Regression Results
# ==================================================================================================================
# Dep. Variable:     Fertility rate, total (births per woman) 2013   R-squared (uncentered):                   0.761
# Model:                                                       OLS   Adj. R-squared (uncentered):              0.759
# Method:                                            Least Squares   F-statistic:                              530.7
# Date:                                           Tue, 01 Sep 2020   Prob (F-statistic):                    9.92e-54
# Time:                                                   23:16:00   Log-Likelihood:                         -309.75
# No. Observations:                                            168   AIC:                                      621.5
# Df Residuals:                                                167   BIC:                                      624.6
# Df Model:                                                      1
# Covariance Type:                                       nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# GDP (current US$) 2013     0.1098      0.005     23.038      0.000       0.100       0.119
# ==============================================================================
# Omnibus:                       18.595   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.221
# Skew:                           0.878   Prob(JB):                     1.50e-05
# Kurtosis:                       2.701   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
