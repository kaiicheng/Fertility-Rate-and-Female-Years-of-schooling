# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Fertility Education Level Gerenal Linear Model Data 2013.xlsx")
df.head(15)
# Out:
#     Country_Name  Fertility rate, total (births per woman) 2013  \
# 0    Afghanistan                                          5.359
# 1        Albania                                          1.690
# 2        Algeria                                          2.990
# 3      Argentina                                          2.322
# 4        Armenia                                          1.728
# 5      Australia                                          1.855
# 6        Austria                                          1.440
# 7     Azerbaijan                                          1.980
# 8   Bahamas, The                                          1.810
# 9        Bahrain                                          2.098
# 10    Bangladesh                                          2.188
# 11      Barbados                                          1.630
# 12       Belarus                                          1.668
# 13       Belgium                                          1.760
# 14        Belize                                          2.539
#
#     GDP per capita (current US$) 2013  GDP (current US$) 2013  \
# 0                          637.165523            2.056107e+10
# 1                         4413.060861            1.277622e+10
# 2                         5499.581487            2.097548e+11
# 3                        13080.254732            5.520251e+11
# 4                         3838.185801            1.112147e+10
# 5                        68150.107041            1.576184e+12
# 6                        50716.708706            4.300687e+11
# 7                         7875.756953            7.416444e+10
# 8                        28768.029894            1.056270e+10
# 9                        24744.296959            3.253947e+10
# 10                         981.839879            1.499905e+11
# 11                       16451.163576            4.677000e+09
# 12                        7978.872615            7.552798e+10
# 13                       46744.662544            5.216427e+11
# 14                        4568.502958            1.579400e+09
#
#     Birth rate, crude (per 1,000 people) 2013  \
# 0                                      36.670
# 1                                      12.257
# 2                                      25.451
# 3                                      17.831
# 4                                      15.125
# 5                                      13.300
# 6                                       9.400
# 7                                      18.300
# 8                                      14.485
# 9                                      15.727
# 10                                     19.862
# 11                                     11.067
# 12                                     12.500
# 13                                     11.300
# 14                                     22.395
#
#     Mean years of schooling, female (years) 2013
# 0                                            1.4
# 1                                            9.8
# 2                                            6.0
# 3                                           10.5
# 4                                           11.5
# 5                                           12.2
# 6                                           11.5
# 7                                           10.2
# 8                                           11.5
# 9                                            8.9
# 10                                           4.7
# 11                                          10.8
# 12                                          12.0
# 13                                          11.2
# 14                                           9.4

# %%
df
# Out:
#     Country_Name  Fertility rate, total (births per woman) 2013  \
# 0    Afghanistan                                          5.359
# 1        Albania                                          1.690
# 2        Algeria                                          2.990
# 3      Argentina                                          2.322
# 4        Armenia                                          1.728
# ..           ...                                            ...
# 163      Vietnam                                          1.978
# 164  Yemen, Rep.                                          4.326
# 165       Zambia                                          5.132
# 166     Zimbabwe                                          4.030
# 167       Taiwan                                          1.070
#
#      GDP per capita (current US$) 2013  GDP (current US$) 2013  \
# 0                           637.165523            2.056107e+10
# 1                          4413.060861            1.277622e+10
# 2                          5499.581487            2.097548e+11
# 3                         13080.254732            5.520251e+11
# 4                          3838.185801            1.112147e+10
# ..                                 ...                     ...
# 163                        1886.671896            1.712220e+11
# 164                        1607.152365            4.041524e+10
# 165                        1878.907001            2.804551e+10
# 166                        1430.000818            1.909102e+10
# 167                       21973.000000            5.129570e+11
#
#      Birth rate, crude (per 1,000 people) 2013  \
# 0                                       36.670
# 1                                       12.257
# 2                                       25.451
# 3                                       17.831
# 4                                       15.125
# ..                                         ...
# 163                                     17.333
# 164                                     33.229
# 165                                     39.339
# 166                                     35.768
# 167                                      8.500
#
#      Mean years of schooling, female (years) 2013
# 0                                             1.4
# 1                                             9.8
# 2                                             6.0
# 3                                            10.5
# 4                                            11.5
# ..                                            ...
# 163                                           7.5
# 164                                           1.7
# 165                                           6.2
# 166                                           7.3
# 167                                          11.2
#
# [168 rows x 6 columns]

# %%
print(df['Birth rate, crude (per 1,000 people) 2013'])
# Out:
# 0      36.670
# 1      12.257
# 2      25.451
# 3      17.831
# 4      15.125
#         ...
# 163    17.333
# 164    33.229
# 165    39.339
# 166    35.768
# 167     8.500
# Name: Birth rate, crude (per 1,000 people) 2013, Length: 168, dtype: float64

# %%
print(df['GDP per capita (current US$) 2013'])
# Out:
# 0        637.165523
# 1       4413.060861
# 2       5499.581487
# 3      13080.254732
# 4       3838.185801
#            ...
# 163     1886.671896
# 164     1607.152365
# 165     1878.907001
# 166     1430.000818
# 167    21973.000000
# Name: GDP per capita (current US$) 2013, Length: 168, dtype: float64

# %%
X = df['GDP per capita (current US$) 2013']
y = df['Birth rate, crude (per 1,000 people) 2013']

# %%
X
# Out:
# 0        637.165523
# 1       4413.060861
# 2       5499.581487
# 3      13080.254732
# 4       3838.185801
#            ...
# 163     1886.671896
# 164     1607.152365
# 165     1878.907001
# 166     1430.000818
# 167    21973.000000
# Name: GDP per capita (current US$) 2013, Length: 168, dtype: float64

# %%
y
# Out:
# 0      36.670
# 1      12.257
# 2      25.451
# 3      17.831
# 4      15.125
#         ...
# 163    17.333
# 164    33.229
# 165    39.339
# 166    35.768
# 167     8.500
# Name: Birth rate, crude (per 1,000 people) 2013, Length: 168, dtype: float64

# %%
length = len(df['Country_Name'])

# %%
country_name = df['Country_Name']

# %%
country_tag = df['Country_Name']

# %%
# Create a plot.
plt.figure(figsize = (20, 15))

plt.scatter(X, y)
plt.title("2013")
plt.xlabel("GDP per capita (current US$)")
plt.ylabel("Birth rate, crude (per 1,000 people)")

# Add country name tag.
for i in range(length):
    if country_name[i] == "Taiwan":
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "green", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)
    else:
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "r", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)

plt.show()

# %%
X = sm.add_constant(X, prepend=False)

# %%
# Ordinary least square method.
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Birth rate, crude (per 1,000 people) 2013   R-squared:                       0.289
# Model:                                                   OLS   Adj. R-squared:                  0.285
# Method:                                        Least Squares   F-statistic:                     67.61
# Date:                                       Tue, 01 Sep 2020   Prob (F-statistic):           5.47e-14
# Time:                                               23:15:37   Log-Likelihood:                -605.92
# No. Observations:                                        168   AIC:                             1216.
# Df Residuals:                                            166   BIC:                             1222.
# Df Model:                                                  1
# Covariance Type:                                   nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# GDP per capita (current US$) 2013    -0.0003   3.37e-05     -8.223      0.000      -0.000      -0.000
# const                                25.5080      0.856     29.795      0.000      23.818      27.198
# ==============================================================================
# Omnibus:                       13.545   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.429
# Skew:                           0.399   Prob(JB):                       0.0148
# Kurtosis:                       2.247   Cond. No.                     3.14e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Replace X with log(X)

# %%
X = df['GDP per capita (current US$) 2013']

# %%
X
# Out:
# 0        637.165523
# 1       4413.060861
# 2       5499.581487
# 3      13080.254732
# 4       3838.185801
#            ...
# 163     1886.671896
# 164     1607.152365
# 165     1878.907001
# 166     1430.000818
# 167    21973.000000
# Name: GDP per capita (current US$) 2013, Length: 168, dtype: float64

# %%
X = np.log(X)

# %%
X
# Out:
# 0      6.457029
# 1      8.392324
# 2      8.612427
# 3      9.478859
# 4      8.252755
#          ...
# 163    7.542570
# 164    7.382219
# 165    7.538446
# 166    7.265430
# 167    9.997570
# Name: GDP per capita (current US$) 2013, Length: 168, dtype: float64

# %%
# Create a plot.
plt.figure(figsize = (20, 15))

plt.scatter(X, y)
plt.title("2013")
plt.xlabel("GDP per capita (current US$)")
plt.ylabel("Birth rate, crude (per 1,000 people)")

# Add country name tag.
for i in range(length):
    if country_name[i] == "Taiwan":
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "green", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)
    else:
        plt.text(X[i], y[i]*1.02, country_name[i], fontsize=10, color = "r", style = "italic", weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0)

plt.show()

# %%
# Ordinary least square method.
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                             OLS Regression Results
# ==============================================================================================================
# Dep. Variable:     Birth rate, crude (per 1,000 people) 2013   R-squared (uncentered):                   0.682
# Model:                                                   OLS   Adj. R-squared (uncentered):              0.680
# Method:                                        Least Squares   F-statistic:                              358.5
# Date:                                       Tue, 01 Sep 2020   Prob (F-statistic):                    2.00e-43
# Time:                                               23:15:39   Log-Likelihood:                         -674.86
# No. Observations:                                        168   AIC:                                      1352.
# Df Residuals:                                            167   BIC:                                      1355.
# Df Model:                                                  1
# Covariance Type:                                   nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# GDP per capita (current US$) 2013     2.2330      0.118     18.934      0.000       2.000       2.466
# ==============================================================================
# Omnibus:                       26.971   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.216
# Skew:                           0.506   Prob(JB):                      0.00135
# Kurtosis:                       2.071   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
